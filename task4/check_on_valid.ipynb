# %%
import pandas as pd

df = pd.read_json('dataset.json')
df
# Out:
#              id                          name  category size       color  \
# 0     756375767          Adidas Jacket C-7397    Jacket  XXL     Зеленый
# 1     621170751             DC T-shirt A-5791   T-shirt    M  Фиолетовый
# 2     271336226  Under Armour Handbags Q-4451  Handbags    M     Красный
# 3     532204928         Brooks T-shirt P-8374   T-shirt    S     Зеленый
# 4     190521293               Nike Hat J-2325       Hat  XXL     Голубой
# ...         ...                           ...       ...  ...         ...
# 2816  644226636            Vans Gloves K-9455    Gloves    M       Синий
# 2817  714392037           Brooks Jeans R-6596     Jeans    S     Зеленый
# 2818  705088546          Lacoste Jeans C-3249     Jeans  XXL     Голубой
# 2819  284072063     New Balance Jacket W-7007    Jacket    L   Оранжевый
# 2820  238809251          Addidas Socks W-2052     Socks    M   Оранжевый
#
#        material   price  rating  reviews exclusive file_name  new sporty
# ...

# %%
h_df = pd.read_json('handled_dataset.json')
h_df.groupby(by='material').describe()
# Out:
#              id                                                         \
#           count          mean           std          min           25%
# material
# Вискоза   339.0  5.729587e+08  2.564211e+08  108338752.0  3.567437e+08
# Кожа      367.0  5.378126e+08  2.624388e+08  104691228.0  3.208870e+08
# Лен       336.0  5.978524e+08  2.546363e+08  102276483.0  3.792351e+08
# Хлопок    355.0  5.432932e+08  2.629316e+08  100622007.0  3.134118e+08
# Шелк      360.0  5.674391e+08  2.652296e+08  103588061.0  3.344083e+08
# Шерсть    367.0  5.713467e+08  2.591759e+08  101846056.0  3.583405e+08
#
#                                                  price                 ...  \
#                   50%          75%          max  count           mean  ...
# material                                                               ...
# Вискоза   614647310.0  779797853.0  998258381.0  339.0  533436.371681  ...
# Кожа      527699113.0  773554029.0  996982330.0  367.0  567894.425068  ...
# ...
